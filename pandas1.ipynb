# %% [markdown]
# 1-D  =>Series
# 0 thi numbring Start thay...

# %%
import pandas as pd 
import numpy as np
marks=[85,90,58,69,81,52]
s=pd.Series(marks)
print(s)
# Out:
# 0    85
# 1    90
# 2    58
# 3    69
# 4    81
# 5    52
# dtype: int64

# %%
import pandas as pd 
marks=[85,90,58,69,81,52]
s=pd.Series(marks,index=["A","B","C","D","E","F"])
print(s)
# Out:
# A    85
# B    90
# C    58
# D    69
# E    81
# F    52
# dtype: int64

# %% [markdown]
# create series by using tuple

# %%
data=("a","b","c")
s=pd.Series(data)
s
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %% [markdown]
# create series by using dictionary

# %% [markdown]
# usiing 2d data

# %%
data={"Name":["Alice","Bob","Charlie"],"Age":[25,30,35],"City":["New York","Los Angeles","Chicago"]}
s1=pd.Series(data)
print(s1)
# Out:
# Name               [Alice, Bob, Charlie]
# Age                         [25, 30, 35]
# City    [New York, Los Angeles, Chicago]
# dtype: object

# %%
data={"name":"A",
        "age":25,
        "city":"New York"   
         }
s2=pd.Series(data)
print(s2)
# Out:
# name           A
# age           25
# city    New York
# dtype: object

# %%
dict={"a":20,"b":10,"c":30}
s3=pd.Series(dict)
s3
# Out:
# a    20
# b    10
# c    30
# dtype: int64

# %%
a=np.array([1,2,3,4,5])
s=pd.Series(a)
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# crete series by using array

# %% [markdown]
# 2-D DataFrame

# %%
data={"Name":["Alice","Bob","Charlie","David"],
"Age":[25,30,35,40],
"City":["New York","Los Angeles","Chicago","UK"],
"employee":[45000,50000,97000,65000],
"position":["Intern","Devloper","HR","CXO"]}
df=pd.DataFrame(data)
df
# Out:
#       Name  Age         City  employee  position
# 0    Alice   25     New York     45000    Intern
# 1      Bob   30  Los Angeles     50000  Devloper
# 2  Charlie   35      Chicago     97000        HR
# 3    David   40           UK     65000       CXO

# %% [markdown]
# Create DataFrame by using List

# %%
data=[["a",80],["B",90],["C",100]]
df=pd.DataFrame(data,columns=["Name","Marks"],index=["10","20","30"])
df
# Out:
#    Name  Marks
# 10    a     80
# 20    B     90
# 30    C    100

# %% [markdown]
# Crete dictionary by Using Pandas Series

# %%
s1=pd.Series([1,2,3])
s2=pd.Series([8,9,10])
df=pd.DataFrame({"col1":s1,"Col2":s2})
df
# Out:
#    col1  Col2
# 0     1     8
# 1     2     9
# 2     3    10

# %% [markdown]
# How to Read csv File|

# %%
df=pd.read_csv("matches.csv")
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# Loc function

# %%
df.loc[3:10]
# Out:
#     id  season       city        date                        team1  \
# 3    4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4    5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5    6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6    7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7    8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8    9    2017       Pune  2017-04-11             Delhi Daredevils
# 9   10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
# 10  11    2017    Kolkata  2017-04-13              Kings XI Punjab
#
#                      team2                  toss_winner toss_decision  result  \
# 3          Kings XI Punjab              Kings XI Punjab         field  normal
# 4         Delhi Daredevils  Royal Challengers Bangalore           bat  normal
# 5      Sunrisers Hyderabad          Sunrisers Hyderabad         field  normal
# ...

# %%
df.loc[3:10,["id","city","date"]]
# Out:
#     id       city        date
# 3    4     Indore  2017-04-08
# 4    5  Bangalore  2017-04-08
# 5    6  Hyderabad  2017-04-09
# 6    7     Mumbai  2017-04-09
# 7    8     Indore  2017-04-10
# 8    9       Pune  2017-04-11
# 9   10     Mumbai  2017-04-12
# 10  11    Kolkata  2017-04-13

# %%
# column fatch karva mate...
df[["team1","team2","toss_winner"]]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                      toss_winner
# 0    Royal Challengers Bangalore
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %% [markdown]
# iloc function

# %% [markdown]
# in this function (end-1) fundamental are working

# %%
df.iloc[3:9,4:6]
# df.iloc[row,column]
# Out:
#                          team1                   team2
# 3       Rising Pune Supergiant         Kings XI Punjab
# 4  Royal Challengers Bangalore        Delhi Daredevils
# 5                Gujarat Lions     Sunrisers Hyderabad
# 6        Kolkata Knight Riders          Mumbai Indians
# 7  Royal Challengers Bangalore         Kings XI Punjab
# 8             Delhi Daredevils  Rising Pune Supergiant

# %% [markdown]
# How to convert DataFrame into csv file

# %%
data={"Name":["Alice","Bob","Charlie","David"],
"Age":[25,30,35,40],
"City":["New York","Los Angeles","Chicago","UK"],
"employee":[45000,50000,97000,65000],
"position":["Intern","Devloper","HR","CXO"]}
df=pd.DataFrame(data)
df
# Out:
#       Name  Age         City  employee  position
# 0    Alice   25     New York     45000    Intern
# 1      Bob   30  Los Angeles     50000  Devloper
# 2  Charlie   35      Chicago     97000        HR
# 3    David   40           UK     65000       CXO

# %%
df.to_csv("a.txt")

# %%
df.describe()
#  describe ne statistical data pan kahe che...
# Out:
#              Age     employee
# count   4.000000      4.00000
# mean   32.500000  64250.00000
# std     6.454972  23428.97067
# min    25.000000  45000.00000
# 25%    28.750000  48750.00000
# 50%    32.500000  57500.00000
# 75%    36.250000  73000.00000
# max    40.000000  97000.00000

# %%
df.info()
#  it will be give all information about daata
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      4 non-null      object
#  1   Age       4 non-null      int64
#  2   City      4 non-null      object
#  3   employee  4 non-null      int64
#  4   position  4 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 292.0+ bytes
